# %% [markdown]
# #### 1. What are the primitive types in python ?
# - Strings
# - Number and
# - Boolean
#
#     - Number is Integer, Float and Complex number

# %% [markdown]
# #### 2. What is the output of the following ?

# %%
fruit = "Apple"
print(fruit[1])
# Out:
# p

# %%
fruit = "Apple"
print(fruit[1 : -1])
# Out:
# ppl

# %% [markdown]
# #### 3. What is the result of this expression ?

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# #### 4. What do you think this output will be ?

# %%
bool("False")
# Out:
# True
